# %% [markdown]
# # Part 1: Regression analysis of Gapminder data
# ## Exercise 1:

# %%
import pandas as pd

gap_data = '/home/jovyan/notebooks/project3/datasets/08_gap-every-five-years.tsv'
data = pd.read_csv(gap_data, sep='\t')
data.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
import numpy as np
import pandas as pd
from plotnine import *

# %matplotlib inline
plot = ggplot(aes(x='year', y='lifeExp'), data=data) + geom_violin() + labs(title="Life expectancy over time", x = "year", y = "life expectancy")
plot
# Out:
# <ggplot: (8727651074154)>
